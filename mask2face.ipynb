# %% [markdown]
# # Mask2Face
# This notebook will guide you through all the steps described in this article to build and train your ML model for removing the face mask of the person's face.

# %%
# Necessary imports
import os
import tarfile
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from utils import download_data
from utils.configuration import Configuration
from utils.data_generator import DataGenerator
from utils.architectures import UNet
from utils.model import Mask2FaceModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       7 from utils import download_data
#       8 from utils.configuration import Configuration
# ----> 9 from utils.data_generator import DataGenerator
#      10 from utils.architectures import UNet
#      11 from utils.model import Mask2FaceModel
#
# File ~/Downloads/CelebAMask-HQ/strv-ml-mask2face-prathamesh/utils/data_generator.py:9
#       7 import shutil
#       8 from utils import image_to_array, load_image, download_data
# ----> 9 from utils.face_detection import crop_face, get_face_keypoints_detecting_function
#      10 from mask_utils.mask_utils import mask_image
#      13 class DataGenerator:
#
# File ~/Downloads/CelebAMask-HQ/strv-ml-mask2face-prathamesh/utils/face_detection.py:9
#       7 import matplotlib.pyplot as plt
#       8 from PIL import Image
# ----> 9 from mtcnn import MTCNN
#      10 from trianglesolver import solve
#      12 from utils import image_to_array
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/mtcnn/__init__.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from mtcnn.mtcnn import MTCNN
#      29 __author__ = "Iván de Paz Centeno"
#      30 __version__= "0.1.0"
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/mtcnn/mtcnn.py:37
#      34 import pkg_resources
#      36 from mtcnn.exceptions import InvalidImage
# ---> 37 from mtcnn.network.factory import NetworkFactory
#      39 __author__ = "Iván de Paz Centeno"
#      42 class StageStatus(object):
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/mtcnn/network/factory.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, PReLU, Flatten, Softmax
#      27 from tensorflow.keras.models import Model
#      29 import numpy as np
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/api/_v2/keras/__init__.py:12
#       3 """Implementation of the Keras API, the high-level API of TensorFlow.
#       4
#       5 Detailed documentation and user guides are available at
#       6 [keras.io](https://keras.io).
#       7
#       8 """
#      10 import sys as _sys
# ---> 12 from keras import __version__
#      13 from keras.api._v2.keras import __internal__
#      14 from keras.api._v2.keras import activations
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/models/__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/engine/functional.py:27
#      24 import tensorflow.compat.v2 as tf
#      26 from keras import backend
# ---> 27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/dtensor/layout_map.py:27
#      25 from keras.dtensor import lazy_variable
#      26 from keras.dtensor import utils
# ---> 27 from keras.engine import base_layer
#      29 # isort: off
#      30 from tensorflow.python.util.deprecation import deprecated
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/engine/base_layer.py:33
#      31 from keras import backend
#      32 from keras import constraints
# ---> 33 from keras import initializers
#      34 from keras import regularizers
#      35 from keras.dtensor import lazy_variable
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/initializers/__init__.py:23
#      21 from keras.initializers import initializers_v1
#      22 from keras.initializers import initializers_v2
# ---> 23 from keras.saving.legacy import serialization
#      24 from keras.utils import generic_utils
#      25 from keras.utils import tf_inspect as inspect
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/saving/legacy/serialization.py:23
#      19 import weakref
#      21 import tensorflow.compat.v2 as tf
# ---> 23 from keras.utils import tf_contextlib
#      24 from keras.utils import tf_inspect
#      26 # isort: off
#
# File /opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/utils/__init__.py:17
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Public Keras utilities."""
# ---> 17 from keras.saving.legacy.serialization import deserialize_keras_object
#      18 from keras.saving.legacy.serialization import serialize_keras_object
#      20 # Serialization related
#
# ImportError: cannot import name 'deserialize_keras_object' from partially initialized module 'keras.saving.legacy.serialization' (most likely due to a circular import) (/opt/anaconda3/envs/mask2face/lib/python3.8/site-packages/keras/saving/legacy/serialization.py)

# %%
# setup HW
# from tensorflow.python.compiler.mlcompute import mlcompute; 
# mlcompute.set_mlc_device(device_name='gpu')
# # is GPU available
gpu_physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_physical_devices) > 0:
    tf.config.experimental.set_memory_growth(gpu_physical_devices[0], True)

# # check HW availability
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.experimental.list_physical_devices('CPU')))

# %% [markdown]
# ## 1) Preconditions
# First we need a dataset of human faces.

# %%
# Check if dataset is already downloaded or needs to be downloaded.
configuration = Configuration()
dataset_path = configuration.get('input_images_path')
if os.path.isdir(dataset_path):
    print('Dataset already downloaded')
else:
    # print('Downloading dataset')
    dataset_archive_path = '/Users/prathmeshpawar/Downloads/CelebAMask-HQ/strv-ml-mask2face/lfw-deepfunneled.tgz'
    # download_data(configuration.get('dataset_archive_download_url'), dataset_archive_path)
    print('Extracting dataset')
    tar = tarfile.open(dataset_archive_path, 'r:gz')
    tar.extractall('data')
    tar.close()
    print('Done')

# %% [markdown]
# ## 2) Data generation
# Next step is to generate data for neural network training. We need input images (person with a face mask) and corresponding output image (the same image as input but without the face mask). We already have output images in downloaded dataset. Input images will be created by adding mask on the faces with a help from [MaskTheFace GitHub](https://github.com/aqeelanwar/MaskTheFace) project.

# %%
# setup the pipeline and generate data

dg = DataGenerator(configuration)

train_folder = configuration.get('train_data_path')
test_folder = configuration.get('test_data_path')

if os.path.exists(train_folder) and os.path.exists(test_folder):
    print('Testing and training data already generated')
else:
    dg.generate_images()

print('Here are few examples of generated data.')
n_examples = 5
inputs, outputs = dg.get_dataset_examples(n_examples)
f, axarr = plt.subplots(2, n_examples, figsize=(20, 10))
for i in range(len(inputs)):
    axarr[1, i].imshow(mpimg.imread(inputs[i]))
    axarr[1, i].axis('off')
    axarr[0, i].imshow(mpimg.imread(outputs[i]))
    axarr[0, i].axis('off')

# %% [markdown]
# ## 3) Model training
# Now we have all the data, and we can initiate model and start training.

# %%
# Feel free to experiment with the number of filters, their sizes or any other parameters
filters = (64, 128, 128, 256, 256, 512)
kernels = (7, 7, 7, 3, 3, 3)
input_image_size = (256, 256, 3)
architecture = UNet.RESNET
training_epochs = 25 # 20
batch_size = 12

# %%
# Create instance of model and start training
# model = Mask2FaceModel.build_model(architecture=architecture, input_size=input_image_size, filters=filters,
#                                    kernels=kernels, configuration=configuration)
# model.train(epochs=training_epochs, batch_size=batch_size, loss_function='ssim_l1_loss')

# If you already have pretrained model you can uncomment next line and load it instead of training new one
model = Mask2FaceModel.load_model('/Users/prathmeshpawar/Downloads/CelebAMask-HQ/strv-ml-mask2face-prathamesh/models/model_epochs-10_batch-12_loss-ssim_l1_loss_20240220_00_58_27.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 # Create instance of model and start training
#       2 # model = Mask2FaceModel.build_model(architecture=architecture, input_size=input_image_size, filters=filters,
#       3 #                                    kernels=kernels, configuration=configuration)
#       4 # model.train(epochs=training_epochs, batch_size=batch_size, loss_function='ssim_l1_loss')
#       5
#       6 # If you already have pretrained model you can uncomment next line and load it instead of training new one
# ----> 7 model = Mask2FaceModel.load_model('/Users/prathmeshpawar/Downloads/CelebAMask-HQ/strv-ml-mask2face-prathamesh/models/model_epochs-10_batch-12_loss-ssim_l1_loss_20240220_00_58_27.h5')
#
# NameError: name 'Mask2FaceModel' is not defined

# %% [markdown]
# ## 4) Results
# Our model is trained, and we can look at it's performance

# %%
# Let's see the results on a random testing image unseen by the model before.
# Run this cell multiple times to see different results
n_examples = 7
input_imgs, true_output_imgs = dg.get_dataset_examples(n_examples, test_dataset=False)
f, axarr = plt.subplots(n_examples, 3, figsize=(10, n_examples * 3))
for i, img in enumerate(input_imgs):
    generated_output = model.predict(img)
    axarr[i, 0].imshow(mpimg.imread(input_imgs[i]))
    axarr[i, 0].axis('off')
    axarr[i, 1].imshow(mpimg.imread(true_output_imgs[i]))
    axarr[i, 1].axis('off')
    axarr[i, 2].imshow(generated_output)
    axarr[i, 2].axis('off')

sample = model.predict('/Users/prathmeshpawar/Downloads/maskedsample.jpeg')
imshow(sample)
axarr[0, 0].set_title('Input images')
axarr[0, 1].set_title('Real outputs')
axarr[0, 2].set_title('Generated outputs')
print('Outputs generated on previously unseen data.')
# Out:
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2024-02-21 09:16:58.118996: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-21 09:16:58.239467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 6/6 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 50ms/step
# (891, 943)
# 2024-02-21 09:16:58.647944: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-21 09:16:58.750376: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-02-21 09:16:58.893227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 12ms/step
# (879, 1015)
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step
# (965, 1024)
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 9/9 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# (1021, 1024)
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 14/14 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# (899, 1024)
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 8ms/step
# 9/9 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# (861, 987)
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 6/6 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 10ms/step
# (846, 1024)
# 1/1 [==============================] - 0s 14ms/step
# Outputs generated on previously unseen data.

# %% [markdown]
# #
